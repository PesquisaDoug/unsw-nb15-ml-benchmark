# %% [markdown]
# # Supervised benchmark
#
# Loads tuning, CV, official test, bootstrap, attack-wise, and permutation-importance outputs.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
pd.read_csv(ROOT / 'results' / 'metrics.csv')

# %%
pd.read_csv(ROOT / 'results' / 'attackwise_detection.csv').head()
