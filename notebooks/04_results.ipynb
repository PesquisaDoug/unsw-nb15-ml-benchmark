# %% [markdown]
# # Consolidated results
#
# Organized around the four research questions.

# %% [markdown]
# ## RQ1 - Supervised benchmark

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
pd.read_csv(ROOT / 'results' / 'metrics.csv')

# %% [markdown]
# ## RQ2 - Attack-wise detection

# %%
pd.read_csv(ROOT / 'results' / 'attackwise_detection.csv')

# %% [markdown]
# ## RQ3 - Unsupervised structure

# %%
pd.read_csv(ROOT / 'results' / 'clustering_metrics.csv')

# %% [markdown]
# ## RQ4 - Computational efficiency

# %%
pd.read_csv(ROOT / 'results' / 'metrics.csv')[['model', 'final_fit_time_seconds', 'inference_us_per_record_median', 'model_size_mb']]
