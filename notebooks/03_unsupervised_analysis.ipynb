# %% [markdown]
# # Unsupervised analysis
#
# Loads PCA, k-Means, DBSCAN, and clustering metrics generated by `scripts.run_clustering`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
pd.read_csv(ROOT / 'results' / 'clustering_metrics.csv')

# %%
pd.read_csv(ROOT / 'results' / 'dbscan_parameter_search.csv').head()
