# %% [markdown]
# # Data exploration
#
# Lightweight notebook that reuses `src.data` and reads outputs produced by the scripts.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
pd.read_csv(ROOT / 'results' / 'data_quality_summary.csv')

# %%
pd.read_csv(ROOT / 'results' / 'schema_summary.csv').head(20)
